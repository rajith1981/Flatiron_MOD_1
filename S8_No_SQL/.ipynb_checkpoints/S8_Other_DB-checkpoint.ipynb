# %% [markdown]
# # Section 08 - No SQL lessons and labs
#
# [nosql-databases-section-intro](./dsc-nosql-databases-section-intro-onl01-dtsc-ft-030220/index.ipynb)<br>
#
#
# [nosql-document-stores-v2-1](./dsc-nosql-document-stores-v2-1-onl01-dtsc-ft-030220/index.ipynb)<br>
#
#
# [mongodb](./dsc-mongodb-onl01-dtsc-ft-030220/index.ipynb)<br>
#
#
# [mongodb-lab](./dsc-mongodb-lab-onl01-dtsc-ft-030220/index.ipynb)<br>
#
#
# [nosql-databases-section-recap-v2-1](./dsc-nosql-databases-section-recap-v2-1-onl01-dtsc-ft-030220/index.ipynb)<br>
